# %%
import pandas as pd
import numpy as np

# %%
january_data = pd.read_csv(r'C:\Users\rashid\Desktop\funnel_analysis\data\raw\2020-Jan.csv')
february_data = pd.read_csv(r'C:\Users\rashid\Desktop\funnel_analysis\data\raw\2020-Feb.csv')

# %%
df_merged = pd.concat([january_data, february_data], ignore_index=True)

# %%
df_merged.to_csv(r'C:\Users\rashid\Desktop\funnel_analysis\data\merged\merged_data.csv', index=False)
